# %% [markdown]
# ### Check GPU hardware

# %%
# !nvidia-smi

# %% [markdown]
# ### Save hardware configuration

# %%
# Create the summary file
# !echo "Hardware Summary" > hardware_summary.txt

# Fetch and write CPU Information
# !echo "\nCPU Information:" >> hardware_summary.txt
# !echo "-----------------" >> hardware_summary.txt
# !lscpu | egrep 'Model name|Socket|Thread|CPU\(s\)' >> hardware_summary.txt

# Fetch and write Total RAM Information
# !echo "\nTotal RAM Information:" >> hardware_summary.txt
# !echo "-----------------" >> hardware_summary.txt
# !free -h | grep Mem | awk '{print $2}' >> hardware_summary.txt


# Fetch and write GPU Information
# !echo "\nGPU Information:" >> hardware_summary.txt
# !echo "-----------------" >> hardware_summary.txt

# If you have a Nvidia GPU
# !nvidia-smi --query-gpu=gpu_name,driver_version,memory.total --format=csv >> hardware_summary.txt

# Alternatively for other GPUs
# !lspci | grep VGA >> hardware_summary.txt

# %% [markdown]
# ### Install D-SCRIPT

# %%
# !pip install dscript
# Out:
# Collecting dscript
#   Downloading dscript-0.2.8-py3-none-any.whl.metadata (474 bytes)
# Requirement already satisfied: numpy in /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from dscript) (2.0.2)
# Requirement already satisfied: scipy in /home/insybio/.local/lib/python3.10/site-packages (from dscript) (1.14.1)
# Requirement already satisfied: pandas in /home/insybio/.local/lib/python3.10/site-packages (from dscript) (2.2.3)
# Requirement already satisfied: torch>=1.11 in /home/insybio/.local/lib/python3.10/site-packages (from dscript) (2.5.1)
# Requirement already satisfied: biopython in /home/insybio/.local/lib/python3.10/site-packages (from dscript) (1.79)
# Requirement already satisfied: matplotlib in /home/insybio/.local/lib/python3.10/site-packages (from dscript) (3.9.2)
# Collecting seaborn (from dscript)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: tqdm in /home/insybio/.local/lib/python3.10/site-packages (from dscript) (4.66.5)
# Requirement already satisfied: scikit-learn in /home/insybio/.local/lib/python3.10/site-packages (from dscript) (1.2.2)
# Requirement already satisfied: h5py in /home/insybio/.local/lib/python3.10/site-packages (from dscript) (3.12.1)
# Requirement already satisfied: filelock in /home/insybio/.local/lib/python3.10/site-packages (from torch>=1.11->dscript) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/insybio/.local/lib/python3.10/site-packages (from torch>=1.11->dscript) (4.12.2)
# Requirement already satisfied: networkx in /home/insybio/.local/lib/python3.10/site-packages (from torch>=1.11->dscript) (3.4.2)
# Requirement already satisfied: jinja2 in /home/insybio/.local/lib/python3.10/site-packages (from torch>=1.11->dscript) (3.1.4)
# Requirement already satisfied: fsspec in /home/insybio/.local/lib/python3.10/site-packages (from torch>=1.11->dscript) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/insybio/.local/lib/python3.10/site-packages (from torch>=1.11->dscript) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/insybio/.local/lib/python3.10/site-packages (from torch>=1.11->dscript) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/insybio/.local/lib/python3.10/site-packages (from torch>=1.11->dscript) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/insybio/.local/lib/python3.10/site-packages (from torch>=1.11->dscript) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/insybio/.local/lib/python3.10/site-packages (from torch>=1.11->dscript) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/insybio/.local/lib/python3.10/site-packages (from torch>=1.11->dscript) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/insybio/.local/lib/python3.10/site-packages (from torch>=1.11->dscript) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/insybio/.local/lib/python3.10/site-packages (from torch>=1.11->dscript) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/insybio/.local/lib/python3.10/site-packages (from torch>=1.11->dscript) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/insybio/.local/lib/python3.10/site-packages (from torch>=1.11->dscript) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/insybio/.local/lib/python3.10/site-packages (from torch>=1.11->dscript) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/insybio/.local/lib/python3.10/site-packages (from torch>=1.11->dscript) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/insybio/.local/lib/python3.10/site-packages (from torch>=1.11->dscript) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/insybio/.local/lib/python3.10/site-packages (from torch>=1.11->dscript) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/insybio/.local/lib/python3.10/site-packages (from sympy==1.13.1->torch>=1.11->dscript) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/insybio/.local/lib/python3.10/site-packages (from matplotlib->dscript) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/insybio/.local/lib/python3.10/site-packages (from matplotlib->dscript) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/insybio/.local/lib/python3.10/site-packages (from matplotlib->dscript) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/insybio/.local/lib/python3.10/site-packages (from matplotlib->dscript) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/insybio/.local/lib/python3.10/site-packages (from matplotlib->dscript) (24.1)
# Requirement already satisfied: pillow>=8 in /home/insybio/.local/lib/python3.10/site-packages (from matplotlib->dscript) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/insybio/.local/lib/python3.10/site-packages (from matplotlib->dscript) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/insybio/.local/lib/python3.10/site-packages (from matplotlib->dscript) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/insybio/.local/lib/python3.10/site-packages (from pandas->dscript) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/insybio/.local/lib/python3.10/site-packages (from pandas->dscript) (2024.2)
# Requirement already satisfied: joblib>=1.1.1 in /home/insybio/.local/lib/python3.10/site-packages (from scikit-learn->dscript) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/insybio/.local/lib/python3.10/site-packages (from scikit-learn->dscript) (3.5.0)
# Requirement already satisfied: six>=1.5 in /home/insybio/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->dscript) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from jinja2->torch>=1.11->dscript) (3.0.2)
# Downloading dscript-0.2.8-py3-none-any.whl (38 kB)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn, dscript
# Successfully installed dscript-0.2.8 seaborn-0.13.2
#
# [notice] A new release of pip is available: 24.2 -> 25.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Download trained models

# %%
# Download Human D-SCRIPT model 
# !wget http://cb.csail.mit.edu/cb/dscript/data/models/human_v1.sav
# Out:
# --2025-02-12 16:38:50--  http://cb.csail.mit.edu/cb/dscript/data/models/human_v1.sav
# Resolving cb.csail.mit.edu (cb.csail.mit.edu)... 128.52.131.233
# Connecting to cb.csail.mit.edu (cb.csail.mit.edu)|128.52.131.233|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cb.csail.mit.edu/cb/dscript/data/models/human_v1.sav [following]
# --2025-02-12 16:38:54--  https://cb.csail.mit.edu/cb/dscript/data/models/human_v1.sav
# Connecting to cb.csail.mit.edu (cb.csail.mit.edu)|128.52.131.233|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://cb.csail.mit.edu/dscript/data/models/human_v1.sav [following]
# --2025-02-12 16:38:55--  http://cb.csail.mit.edu/dscript/data/models/human_v1.sav
# Connecting to cb.csail.mit.edu (cb.csail.mit.edu)|128.52.131.233|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cb.csail.mit.edu/dscript/data/models/human_v1.sav [following]
# --2025-02-12 16:38:55--  https://cb.csail.mit.edu/dscript/data/models/human_v1.sav
# Connecting to cb.csail.mit.edu (cb.csail.mit.edu)|128.52.131.233|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2542758 (2.4M)
# Saving to: ‘human_v1.sav’
#
# human_v1.sav        100%[===================>]   2.42M  2.56MB/s    in 0.9s
#
# 2025-02-12 16:38:57 (2.56 MB/s) - ‘human_v1.sav’ saved [2542758/2542758]

# %% [markdown]
# ### Download sequence and interaction files for test datasets

# %%
# !wget https://raw.githubusercontent.com/anhvt00/MCAPS/master/data/Dscript-data/pairs/ecoli_test.tsv
# !wget https://raw.githubusercontent.com/anhvt00/MCAPS/master/data/Dscript-data/seqs/ecoli.fasta
# Out:
# --2025-02-12 16:39:10--  https://raw.githubusercontent.com/anhvt00/MCAPS/master/data/Dscript-data/pairs/ecoli_test.tsv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8000::154, 2606:50c0:8003::154, 2606:50c0:8001::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8000::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 812468 (793K) [text/plain]
# Saving to: ‘ecoli_test.tsv’
#
# ecoli_test.tsv      100%[===================>] 793.43K  3.47MB/s    in 0.2s
#
# 2025-02-12 16:39:12 (3.47 MB/s) - ‘ecoli_test.tsv’ saved [812468/812468]
#
# --2025-02-12 16:39:12--  https://raw.githubusercontent.com/anhvt00/MCAPS/master/data/Dscript-data/seqs/ecoli.fasta
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8001::154, 2606:50c0:8002::154, 2606:50c0:8000::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8001::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5413511 (5.2M) [text/plain]
# Saving to: ‘ecoli.fasta’
#
# ecoli.fasta         100%[===================>]   5.16M  8.81MB/s    in 0.6s
#
# 2025-02-12 16:39:13 (8.81 MB/s) - ‘ecoli.fasta’ saved [5413511/5413511]

# %% [markdown]
# ### Generate embeddings

# %%
# !dscript embed --seqs TEST_seqs.fasta -o TEST_emb.h5 -d 0
# Out:
# [2025-02-12-21:34:40] # Using CPU
# [2025-02-12-21:34:40] # Loading Model...
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/pretrained.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path)
# [2025-02-12-21:34:40] # Loading Sequences...
# 100%|███████████████████████████████████| 6879/6879 [00:00<00:00, 181564.63it/s]
# [2025-02-12-21:34:41] # 6879 Sequences Loaded
# [2025-02-12-21:34:41] # Approximate Storage Required (varies by average sequence length): ~55.032000000000004GB
# [2025-02-12-21:34:41] # Storing to TEST_emb.h5...
# 100%|█████████████████████████████████████| 6879/6879 [1:15:01<00:00,  1.53it/s]

# %% [markdown]
# ### Evaluate on test dataset

# %%
# Evaluate with Human D-SCRIPT model 
# !dscript evaluate --model human_v1.sav --test ecoli_test.tsv --embedding ecoli.h5 --outfile ecoli_dscript
# Out:
# [2025-02-13-00:39:54] Using CPU
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path, map_location=torch.device("cpu")).cpu()
#   0%|                                                  | 0/7138 [00:00<?, ?it/s]
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/insybio/.pyenv/versions/3.10.12/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/utils.py", line 53, in _hdf5_load_partial_func
#     with h5py.File(file_path, "r") as fi:
#   File "/home/insybio/.local/lib/python3.10/site-packages/h5py/_hl/files.py", line 561, in __init__
#     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#   File "/home/insybio/.local/lib/python3.10/site-packages/h5py/_hl/files.py", line 235, in make_fid
#     fid = h5f.open(name, flags, fapl=fapl)
#   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "h5py/h5f.pyx", line 102, in h5py.h5f.open
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = 'ecoli.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/insybio/.pyenv/versions/3.10.12/bin/dscript", line 8, in <module>
#     sys.exit(main())
#   File "/home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/__main__.py", line 77, in main
#     args.func(args)
#   File "/home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py", line 217, in main
#     embeddings = load_hdf5_parallel(embPath, allProteins)
#   File "/home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/utils.py", line 75, in load_hdf5_parallel
#     all_embs = list(
#   File "/home/insybio/.local/lib/python3.10/site-packages/tqdm/std.py", line 1181, in __iter__
#     for obj in iterable:
#   File "/home/insybio/.pyenv/versions/3.10.12/lib/python3.10/multiprocessing/pool.py", line 873, in next
#     raise value
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = 'ecoli.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
import os
import pandas as pd
import subprocess
import time
import gc

# Define file paths
input_file = 'TEST_ppis_r.tsv'
model = 'human_v1.sav'
embedding = 'TEST_emb.h5'
output_file = 'TEST_dscript.predictions.tsv'

# Create a subfolder for chunk files and predictions
output_dir = 'TEST_chunks_and_predictions_2'
os.makedirs(output_dir, exist_ok=True)

# Load the dataset
df = pd.read_csv(input_file, sep='\t')

# Define chunk size (adjust based on memory)
chunk_size = 100  # Modify as needed
num_chunks = len(df) // chunk_size + (1 if len(df) % chunk_size != 0 else 0)

# Prepare the final output file
final_output_path = os.path.join(output_dir, output_file)

# Iterate through each chunk, process it, and merge results
for i in range(num_chunks):
    # Create chunk of data
    chunk = df.iloc[i * chunk_size: (i + 1) * chunk_size]
    chunk_file = os.path.join(output_dir, f"TEST_test_chunk_{i+1}.tsv")

    # Save the chunk to a file
    chunk.to_csv(chunk_file, sep='\t', index=False, header=False)

    # Define prediction file (it will be created by D-SCRIPT)
    predictions_file = os.path.join(output_dir, f"TEST_test_chunk_{i+1}.predictions.tsv")

    # Run the dscript evaluate command on the chunk
    command = [
        'dscript', 'evaluate',
        '--model', model,
        '--test', chunk_file,
        '--embedding', embedding,
        '--outfile', predictions_file  # Let dscript handle the extension
    ]

    # Execute the command
    result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    # Check if the predictions file was created
    if os.path.exists(predictions_file):
        # Append predictions to the final output file
        with open(predictions_file, 'r') as pred_file, open(final_output_path, 'a') as final_file:
            final_file.writelines(pred_file.readlines())

        # Remove processed chunk file (not predictions)
        os.remove(chunk_file)
        print(f"Processed and merged chunk {i+1}.")
    else:
        print(f"Error: Predictions file for chunk {i+1} was not created. stderr: {result.stderr.decode()}")

    # Manually clear memory
    del chunk
    gc.collect()  # Force garbage collection

    # Pause to prevent memory overload
    time.sleep(5)

print(f"Final predictions saved to {final_output_path}")
# Out:
# Error: Predictions file for chunk 1 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 184/184 [00:13<00:00, 13.47it/s]
# Predicting pairs:  79%|███████▉  | 79/100 [00:16<00:06,  3.24it/s]9606.ENSP00000416097 x 9606.ENSP00000355533 - The size of tensor a (4967) must match the size of tensor b (2000) at non-singleton dimension 3
# Error: Predictions file for chunk 2 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 182/182 [00:11<00:00, 16.00it/s]
# Predicting pairs: 100%|██████████| 100/100 [00:27<00:00,  3.68it/s]606.ENSP00000296755 x 9606.ENSP00000435466 - The size of tensor a (2468) must match the size of tensor b (2000) at non-singleton dimension 2
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1179: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 3 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 180/180 [00:09<00:00, 19.02it/s]
# Predicting pairs:  65%|██████▌   | 65/100 [00:13<00:06,  5.75it/s]/home/insybio/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:549: UserWarning: cuDNN cannot be used for large non-batch-splittable convolutions if the V8 API is not enabled or before cuDNN version 9.3+. Consider upgrading cuDNN and/or enabling the V8 API for better efficiency. (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:430.)
#   return F.conv2d(
# Predicting pairs: 100%|██████████| 100/100 [00:28<00:00,  3.45it/s]606.ENSP00000353362 x 9606.ENSP00000324463 - The size of tensor a (2146) must match the size of tensor b (2000) at non-singleton dimension 3
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1179: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 4 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 182/182 [00:07<00:00, 25.20it/s]
# Predicting pairs:  23%|██▎       | 23/100 [00:04<00:19,  3.94it/s]/home/insybio/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:549: UserWarning: cuDNN cannot be used for large non-batch-splittable convolutions if the V8 API is not enabled or before cuDNN version 9.3+. Consider upgrading cuDNN and/or enabling the V8 API for better efficiency. (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:430.)
#   return F.conv2d(
# Predicting pairs: 100%|██████████| 100/100 [00:22<00:00,  4.51it/s]606.ENSP00000349437 x 9606.ENSP00000339566 - The size of tensor a (2491) must match the size of tensor b (2000) at non-singleton dimension 2
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1179: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 5 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 189/189 [00:07<00:00, 23.68it/s]
# Predicting pairs: 100%|██████████| 100/100 [00:22<00:00,  4.47it/s]606.ENSP00000309052 x 9606.ENSP00000383887 - The size of tensor a (2223) must match the size of tensor b (2000) at non-singleton dimension 3
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1179: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 6 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 180/180 [00:06<00:00, 26.73it/s]
# Predicting pairs: 100%|██████████| 100/100 [00:21<00:00,  4.71it/s]606.ENSP00000326381 x 9606.ENSP00000265104 - The size of tensor a (4624) must match the size of tensor b (2000) at non-singleton dimension 3
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1179: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 7 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 183/183 [00:07<00:00, 24.85it/s]
# Predicting pairs: 100%|██████████| 100/100 [00:22<00:00,  4.50it/s]606.ENSP00000414426 x 9606.ENSP00000323856 - The size of tensor a (4684) must match the size of tensor b (2000) at non-singleton dimension 3
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1179: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 8 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 187/187 [00:07<00:00, 24.62it/s]
# Predicting pairs:  45%|████▌     | 45/100 [00:09<00:14,  3.76it/s]/home/insybio/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:549: UserWarning: cuDNN cannot be used for large non-batch-splittable convolutions if the V8 API is not enabled or before cuDNN version 9.3+. Consider upgrading cuDNN and/or enabling the V8 API for better efficiency. (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:430.)
#   return F.conv2d(
# Predicting pairs: 100%|██████████| 100/100 [00:35<00:00,  2.85it/s]606.ENSP00000358151 x 9606.ENSP00000394510 - The size of tensor a (2036) must match the size of tensor b (2000) at non-singleton dimension 3
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1179: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 9 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 192/192 [00:09<00:00, 20.05it/s]
# Predicting pairs: 100%|██████████| 100/100 [00:23<00:00,  4.31it/s]606.ENSP00000304350 x 9606.ENSP00000266079 - The size of tensor a (2335) must match the size of tensor b (2000) at non-singleton dimension 2
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1179: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 10 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 186/186 [00:08<00:00, 21.20it/s]
# Predicting pairs: 100%|██████████| 100/100 [00:18<00:00,  5.45it/s]606.ENSP00000350882 x 9606.ENSP00000231790 - The size of tensor a (2472) must match the size of tensor b (2000) at non-singleton dimension 2
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1179: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 11 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 188/188 [00:09<00:00, 19.01it/s]
# Predicting pairs: 100%|██████████| 100/100 [00:26<00:00,  3.73it/s]606.ENSP00000321106 x 9606.ENSP00000323856 - The size of tensor a (4684) must match the size of tensor b (2000) at non-singleton dimension 3
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1179: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 12 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 190/190 [00:10<00:00, 18.80it/s]
# Predicting pairs: 100%|██████████| 100/100 [00:23<00:00,  4.32it/s]606.ENSP00000365561 x 9606.ENSP00000323856 - The size of tensor a (4684) must match the size of tensor b (2000) at non-singleton dimension 33
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1179: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 13 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 187/187 [00:06<00:00, 28.51it/s]
# Predicting pairs: 100%|██████████| 100/100 [00:21<00:00,  4.59it/s]606.ENSP00000339527 x 9606.ENSP00000309555 - The size of tensor a (2035) must match the size of tensor b (2000) at non-singleton dimension 3
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1179: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 14 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 190/190 [00:06<00:00, 27.42it/s]
# Predicting pairs: 100%|██████████| 100/100 [00:17<00:00,  5.64it/s]606.ENSP00000353362 x 9606.ENSP00000322016 - The size of tensor a (2506) must match the size of tensor b (2000) at non-singleton dimension 2
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1179: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 15 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 182/182 [00:07<00:00, 24.28it/s]
# Predicting pairs:   3%|▎         | 3/100 [00:01<00:31,  3.04it/s]/home/insybio/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:549: UserWarning: cuDNN cannot be used for large non-batch-splittable convolutions if the V8 API is not enabled or before cuDNN version 9.3+. Consider upgrading cuDNN and/or enabling the V8 API for better efficiency. (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:430.)
#   return F.conv2d(
# Predicting pairs: 100%|██████████| 100/100 [00:39<00:00,  2.56it/s]606.ENSP00000359025 x 9606.ENSP00000344528 - The size of tensor a (6885) must match the size of tensor b (2000) at non-singleton dimension 33
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1179: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 16 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 184/184 [00:08<00:00, 22.93it/s]
# Predicting pairs:  67%|██████▋   | 67/100 [00:11<00:05,  5.75it/s]/home/insybio/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:549: UserWarning: cuDNN cannot be used for large non-batch-splittable convolutions if the V8 API is not enabled or before cuDNN version 9.3+. Consider upgrading cuDNN and/or enabling the V8 API for better efficiency. (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:430.)
#   return F.conv2d(
# Predicting pairs: 100%|██████████| 100/100 [00:26<00:00,  3.77it/s]606.ENSP00000353483 x 9606.ENSP00000295956 - The size of tensor a (2602) must match the size of tensor b (2000) at non-singleton dimension 3
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1179: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 17 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 185/185 [00:06<00:00, 30.11it/s]
# Predicting pairs:  14%|█▍        | 14/100 [00:03<00:37,  2.31it/s]/home/insybio/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:549: UserWarning: cuDNN cannot be used for large non-batch-splittable convolutions if the V8 API is not enabled or before cuDNN version 9.3+. Consider upgrading cuDNN and/or enabling the V8 API for better efficiency. (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:430.)
#   return F.conv2d(
# Predicting pairs: 100%|██████████| 100/100 [00:23<00:00,  4.20it/s]606.ENSP00000360671 x 9606.ENSP00000351575 - The size of tensor a (2624) must match the size of tensor b (2000) at non-singleton dimension 3
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1179: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 18 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 181/181 [00:03<00:00, 46.35it/s]
# Predicting pairs: 100%|██████████| 100/100 [00:18<00:00,  5.29it/s]606.ENSP00000350882 x 9606.ENSP00000364700 - The size of tensor a (2472) must match the size of tensor b (2000) at non-singleton dimension 29606.ENSP00000356448 x 9606.ENSP00000332591 - The size of tensor a (2363) must match the size of tensor b (2000) at non-singleton dimension 2
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1179: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 19 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 185/185 [00:05<00:00, 36.95it/s]
# Predicting pairs: 100%|██████████| 100/100 [00:17<00:00,  5.72it/s]606.ENSP00000437073 x 9606.ENSP00000265070 - The size of tensor a (2054) must match the size of tensor b (2000) at non-singleton dimension 2
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1179: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 20 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 188/188 [00:05<00:00, 35.19it/s]
# Predicting pairs: 100%|██████████| 100/100 [00:24<00:00,  4.16it/s]606.ENSP00000295901 x 9606.ENSP00000380661 - The size of tensor a (2442) must match the size of tensor b (2000) at non-singleton dimension 3
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1179: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 21 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 193/193 [00:04<00:00, 41.73it/s]
# Predicting pairs: 100%|██████████| 100/100 [00:22<00:00,  4.47it/s]606.ENSP00000325376 x 9606.ENSP00000316357 - The size of tensor a (2554) must match the size of tensor b (2000) at non-singleton dimension 3
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1179: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 22 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 183/183 [00:06<00:00, 29.25it/s]
# Predicting pairs: 100%|██████████| 100/100 [00:27<00:00,  3.70it/s]606.ENSP00000308227 x 9606.ENSP00000364912 - The size of tensor a (3664) must match the size of tensor b (2000) at non-singleton dimension 3
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1179: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 23 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 183/183 [00:04<00:00, 37.94it/s]
# Predicting pairs:   6%|▌         | 6/100 [00:00<00:09,  9.67it/s]9606.ENSP00000283256 x 9606.ENSP00000278947 - The size of tensor a (2005) must match the size of tensor b (2000) at non-singleton dimension 2/home/insybio/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:549: UserWarning: cuDNN cannot be used for large non-batch-splittable convolutions if the V8 API is not enabled or before cuDNN version 9.3+. Consider upgrading cuDNN and/or enabling the V8 API for better efficiency. (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:430.)
#   return F.conv2d(
# Predicting pairs: 100%|██████████| 100/100 [00:24<00:00,  4.11it/s]606.ENSP00000316054 x 9606.ENSP00000323856 - The size of tensor a (4684) must match the size of tensor b (2000) at non-singleton dimension 3
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# ...
#   warnings.warn(
#
# Error: Predictions file for chunk 348 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 193/193 [00:01<00:00, 110.69it/s]
# Predicting pairs: 100%|██████████| 100/100 [00:10<00:00,  9.28it/s]606.ENSP00000267884 x 9606.ENSP00000498587 - The size of tensor a (2555) must match the size of tensor b (2000) at non-singleton dimension 3
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 349 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 188/188 [00:01<00:00, 109.47it/s]
# Predicting pairs: 100%|██████████| 100/100 [00:12<00:00,  8.03it/s]606.ENSP00000252999 x 9606.ENSP00000226444 - The size of tensor a (3695) must match the size of tensor b (2000) at non-singleton dimension 2
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 350 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 187/187 [00:01<00:00, 113.56it/s]
# Predicting pairs: 100%|██████████| 100/100 [00:09<00:00, 10.22it/s]606.ENSP00000408800 x 9606.ENSP00000416293 - The size of tensor a (3530) must match the size of tensor b (2000) at non-singleton dimension 2
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 351 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 181/181 [00:01<00:00, 107.37it/s]
# Predicting pairs: 100%|██████████| 100/100 [00:11<00:00,  8.95it/s]606.ENSP00000283256 x 9606.ENSP00000241261 - The size of tensor a (2005) must match the size of tensor b (2000) at non-singleton dimension 29606.ENSP00000252999 x 9606.ENSP00000360644 - The size of tensor a (3695) must match the size of tensor b (2000) at non-singleton dimension 2
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 352 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 189/189 [00:01<00:00, 110.41it/s]
# Predicting pairs: 100%|██████████| 100/100 [00:11<00:00,  8.64it/s]606.ENSP00000164024 x 9606.ENSP00000365596 - The size of tensor a (3312) must match the size of tensor b (2000) at non-singleton dimension 2
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Error: Predictions file for chunk 353 was not created. stderr: /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/dscript/commands/evaluate.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path
# 100%|██████████| 46/46 [00:00<00:00, 57.39it/s]
# Predicting pairs: 100%|██████████| 23/23 [00:03<00:00,  6.24it/s]9606.ENSP00000426664 x 9606.ENSP00000316054 - The size of tensor a (2058) must match the size of tensor b (2000) at non-singleton dimension 2
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# /home/insybio/.pyenv/versions/3.10.12/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#
# Final predictions saved to TEST_chunks_and_predictions_2/TEST_dscript.predictions.tsv

# %%
import os
import glob

# Define paths
input_dir = 'TEST_chunks_and_predictions_2'  # Folder where chunk predictions are stored
output_file = 'TEST_dscript_merged.predictions.tsv'  # Final merged file

# Get all prediction files (sorted to maintain order)
prediction_files = sorted(glob.glob(os.path.join(input_dir, '*.predictions.tsv.predictions.tsv')))

# Merge all prediction files
with open(output_file, 'w') as outfile:
    for file in prediction_files:
        with open(file, 'r') as infile:
            outfile.writelines(infile.readlines())

print(f"Final merged predictions saved to {output_file}")
# Out:
# Final merged predictions saved to TEST_dscript_merged.predictions.tsv

# %% [markdown]
# ### Read prediction file

# %%
import pandas as pd
df = pd.read_csv('TEST_dscript_merged.predictions.tsv', sep='\t', header=None)
print(df)
df = df.drop_duplicates(subset=[0, 1])
print(df)
# Out:
#                           0                     1  2         3
# 0      9606.ENSP00000361032  9606.ENSP00000301761  0  0.004176
# 1      9606.ENSP00000305810  9606.ENSP00000394699  0  0.004176
# 2      9606.ENSP00000364475  9606.ENSP00000362584  0  0.004185
# 3      9606.ENSP00000365176  9606.ENSP00000353854  0  0.004175
# 4      9606.ENSP00000267884  9606.ENSP00000478677  0  0.004239
# ...                     ...                   ... ..       ...
# 34973  9606.ENSP00000261489  9606.ENSP00000256151  1  0.004177
# 34974  9606.ENSP00000376024  9606.ENSP00000345680  1  0.004248
# 34975  9606.ENSP00000341844  9606.ENSP00000318914  1  0.004176
# 34976  9606.ENSP00000252542  9606.ENSP00000252542  1  0.809190
# 34977  9606.ENSP00000193322  9606.ENSP00000372193  1  0.004187
#
# [34978 rows x 4 columns]
#                           0                     1  2         3
# 0      9606.ENSP00000361032  9606.ENSP00000301761  0  0.004176
# 1      9606.ENSP00000305810  9606.ENSP00000394699  0  0.004176
# 2      9606.ENSP00000364475  9606.ENSP00000362584  0  0.004185
# 3      9606.ENSP00000365176  9606.ENSP00000353854  0  0.004175
# 4      9606.ENSP00000267884  9606.ENSP00000478677  0  0.004239
# ...                     ...                   ... ..       ...
# 34973  9606.ENSP00000261489  9606.ENSP00000256151  1  0.004177
# 34974  9606.ENSP00000376024  9606.ENSP00000345680  1  0.004248
# 34975  9606.ENSP00000341844  9606.ENSP00000318914  1  0.004176
# 34976  9606.ENSP00000252542  9606.ENSP00000252542  1  0.809190
# 34977  9606.ENSP00000193322  9606.ENSP00000372193  1  0.004187
#
# [34978 rows x 4 columns]

# %% [markdown]
# ### Compute performance metrics

# %%
# Import necessary libraries
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, fbeta_score, roc_auc_score, confusion_matrix, average_precision_score, matthews_corrcoef

import numpy as np

# Extract prediction and true labels
y_true = df.iloc[:, 2]
y_prob = df.iloc[:, 3]
y_pred = np.round(y_prob)

# Accuracy
acc = accuracy_score(y_true, y_pred) * 100  # Multiply by 100 to convert to percentage

# Precision
prec = precision_score(y_true, y_pred) * 100

# Recall
rec = recall_score(y_true, y_pred) * 100

# Specificity
cm = confusion_matrix(y_true, y_pred)
tn, fp, fn, tp = cm.ravel()
spec = (tn / (tn + fp)) * 100

# MCC score
mcc = matthews_corrcoef(y_true, y_pred)

# F1 score
f1 = f1_score(y_true, y_pred) * 100

# F2 score (using beta=2 to prioritize recall)
f2 = fbeta_score(y_true, y_pred, beta=2) * 100

# AUC-ROC
auroc = roc_auc_score(y_true, y_prob) * 100

# AUPRC
auprc = average_precision_score(y_true, y_prob) * 100

# Print metrics with 2 decimal places
print(f'Accuracy: {acc:.2f}%, Precision: {prec:.2f}%, Recall: {rec:.2f}%, Specificity: {spec:.2f}%, MCC: {mcc:.2f}, F1-Score: {f1:.2f}%, F2-Score: {f2:.2f}%, AUC-ROC: {auroc:.2f}%, AUPRC: {auprc:.2f}%')
# Out:
# Accuracy: 65.88%, Precision: 66.31%, Recall: 6.61%, Specificity: 98.17%, MCC: 0.12, F1-Score: 12.02%, F2-Score: 8.06%, AUC-ROC: 53.70%, AUPRC: 43.23%
